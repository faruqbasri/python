# %%
# OOPS
# OOP stands for Object-Oriented Programming.
# Object-oriented programming (OOP) is a programming paradigm based on the
# concept of "objects"
 
# Procedural programming is about writing procedures or methods that perform operations
# on the data, while object-oriented programming is about creating objects
# that contain both data and methods.
 
# Object-oriented programming has several advantages over procedural programming:
 
# a.) OOP is faster and easier to execute
# b.) OOP provides a clear structure for the programs
# c.) OOP helps to keep the Java/Python code DRY "Don't Repeat Yourself", and makes the code easier
#     to maintain, modify and debug
# d.) OOP makes it possible to create full reusable applications with less code and
#     shorter development time
 
# Class
# A class is a blueprint that defines the variables and the methods common to all objects.
# a class is a collection of methods and variables


# Object
# An object is called an instance of a class.
 
 
# Self Keyword
# The self parameter is a reference to the current instance of the class, and is used to
# access variables that belongs to the class.
# The first parameter of each method in a class must be the self ,
# which refers to the calling object. However, you can give any name to the first
# parameter, not necessarily self.
 
# __init__ in Python
# Constructors are used to initializing the object’s state. The task of constructors is
# to initialize(assign values) to the data members of the class when
# an object of the class is created.
# The __init__() function is called automatically every time the class is being used to create
# a new object.

# %%
# class

# a class is a collection of variables and methods
# variables defined inside class is known as Class Variables / Member Variables
# methods/functions defined inside class is known as Class Methods / Member Methods
# in python we define class using class keyword

class myclass:

    '''
    This is my first class in Python OOP
    '''

    a = 10                  # member variable
    b = 20

    def func1():            # member method
        print(' I am the method of a class')

    def func2():
        print(' I am the another method of a class')

# %%
help(myclass)
# Out:
# Help on class myclass in module __main__:
#
# class myclass(builtins.object)
#  |  This is my first class in Python OOP
#  |
#  |  Methods defined here:
#  |
#  |  func1()
#  |
#  |  func2()
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  a = 10
#  |
#  |  b = 20

# %%
print(myclass.__doc__)    #__doc__  documentation
# Out:
# This is my first class in Python OOP

# %%
# accessing class variables and methods

class myclass:

    a = 10                  
    b = 20

    def func1():         
        print(' I am the method of a class')

    def func2():
        print(' I am the another method of a class')

# Rule 1  (not advisable)
# in order to access class variables and methods
# use classname with dot operator
# dot operator --> member access operator

print(myclass.a)
print(myclass.b)

myclass.func1()
myclass.func2()
# Out:
# 10
# 20
#  I am the method of a class
#  I am the another method of a class

# %%
# Rule 2
# in order to access class variables and methods define an object for a Class
# a class can have n number of objects

class myclass:

    a = 10                  
    b = 20

    def func1():         
        print(' I am the method of a class')

    def func2():
        print(' I am the another method of a class')

obj1 = myclass()         # syntax for creating an object of a class
obj2 = myclass()         # creating another object

print(obj1.a)
print(obj1.b)

print(obj2.a)
print(obj2.b)

obj1.func1()            # cannot
# Out:
# 10
# 20
# 10
# 20
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[89], line 25
#      22 print(obj2.a)
#      23 print(obj2.b)
# ---> 25 print(obj1.func1())
#
# TypeError: myclass.func1() takes 0 positional arguments but 1 was given

# %%
# Rule 2
# in order to access class variables and methods define an object for a Class
# a class can have n number of objects
 
class myclass:
 
    a = 10 
    b = 20
 
    # self represent the current calling object
    # whenever you are defining a function inside a class , first parameter needs to be SELF
    def func1(self):                                        # func1(obj1) giving your class a clear idea that now obj1 wants to use this function
        print(' I am the method of a class')                # func1(obj2) giving your class a clear idea that now obj2 wants to use this function
 
    def func2(self):
        print(' I am the another method of a class')
 
    def func3(self,val1,val2):                              # func3(obj1,10,20)      func3(obj2,30,40)
        print(f'{val1} and {val2}')
 
obj1 = myclass()  # syntax for creating an object of a class
obj2 = myclass()  # creating another object
 
print(obj1.a)
print(obj1.b)
 
print(obj2.a)
print(obj2.b)
 
obj1.func1()
obj2.func1()
 
obj1.func3(10,20)
obj2.func3(30,40)
# Out:
# 10
# 20
# 10
# 20
#  I am the method of a class
#  I am the method of a class
# 10 and 20
# 30 and 40

# %%
-- OOP
-- Rule : if you are defining a function inside a class first Parameter needs to be SELF
 
-----------------------------------------------------------------------
 
class abc:
 
   def func1(self):                                 #  func1(obj1)    func1(obj2)
      print("I am class func")
   def func2(self):
      print("I am class func too")

-------------------------------------------------------------------------
 
A CLASS CAN HAVE n NUMBER OF OBJECTS
 
obj1 = abc()
obj2 = abc()
obj3 = abc()
obj4 = abc()
obj5 = abc()
 
-------------------------------------------------------------------------
 
obj1.func1(self) obj2.func1(self)  obj3.func1()   obj4.func1()   obj5.func1()
 
-------------------------------------------------------------------------

# %%
# Task
# Take 3 information from 3 users
# user1  name   mobno   email
# user2 name   mobno   email
# user3 name   mobno   email
 
# print all information
# print the information of only second user   : user2  name   mobno   email
# print the name and mobno of 3rd user

users = []

for i in range(1,4):
    print(f'Enter User Details {i}')
    
    user = {'name' : input('Name: '), 
            'mobno' : input('Mobile no.: '), 
            'email' : input('Email: ')
           }

    users.append(user)

print("\nAll Users Information:")
for user in users:
    print(user)

print("\nSecond User Information:")
print(users[1]["name"], users[1]["mobno"], users[1]["email"])

print("\nThird User Name and Mobile Number:")
print(users[2]["name"], users[2]["mobno"])
# Out:
# Enter User Details 1
# Name:  AAA
# Mobile no.:  111
# Email:  aaa
# Enter User Details 2
# Name:  BBB
# Mobile no.:  222
# Email:  bbb
# Enter User Details 3
# Name:  CCC
# Mobile no.:  333
# Email:  ccc
# All Users Information:
# {'name': 'AAA', 'mobno': '111', 'email': 'aaa'}
# {'name': 'BBB', 'mobno': '222', 'email': 'bbb'}
# {'name': 'CCC', 'mobno': '333', 'email': 'ccc'}
#
# Second User Information:
# BBB 222 bbb
#
# Third User Name and Mobile Number:
# CCC 333

# %%
userInfo = []

for i in range(1,4):    # 1 2 3             # i --> 1
    name = input('Enter Your Name :')       # name --> abc
    mn = input('Enter Your Mobno :')        # mn --> 123
    email = input('Enter Your Email :')     # email --> abc@g.com

    userInfo.append([name,mn,email])        #[[name,mn,email],[name,mn,email],[name,mn,email]]

print()
print('All Information')
print(userInfo)
# Out:
# Enter Your Name : AAA
# Enter Your Mobno : 111
# Enter Your Email : aaa
# Enter Your Name : BBB
# Enter Your Mobno : 222
# Enter Your Email : bbb
# Enter Your Name : CCC
# Enter Your Mobno : 333
# Enter Your Email : ccc
# All Information
# [['AAA', '111', 'aaa'], ['BBB', '222', 'bbb'], ['CCC', '333', 'ccc']]

# %%
print('All Information')
print(userInfo)
print('\nSecond User Information')
print(userInfo[1])
print('\nName and Mobno of 3rd User')
print(userInfo[2][0],userInfo[2][1])
# Out:
# All Information
# [['abc', 'abc', '@g'], ['def', '456', '@g'], ['ghi', '789', '@g']]
#
# Second User Information
# ['def', '456', '@g']
#
# Name and Mobno of 3rd User
# ghi 789

# %%
userInfo = []

for i in range(1,4):    # 1 2 3                        # i --> 1
    name = input(f'Enter Details of User {i} :')       # name --> abc
    mn = input('Enter Your Mobno :')                   # mn --> 123
    email = input('Enter Your Email :')                # email --> abc@g.com

    userInfo.append([name,mn,email])                   #[[name,mn,email],[name,mn,email],[name,mn,email]]
print('\nAll Information')
print(userInfo)
# Out:
# Enter Details of User 1 : abc
# Enter Your Mobno : 123
# Enter Your Email : @g
# Enter Details of User 2 : def
# Enter Your Mobno : 456
# Enter Your Email : @g
# Enter Details of User 3 : ghi
# Enter Your Mobno : 789
# Enter Your Email : @g
# All Information
# [['abc', '123', '@g'], ['def', '456', '@g'], ['ghi', '789', '@g']]

# %%
print('All Information')
for i in range(3):
    print(f'Showing Details Of User {i+1} : {userInfo[i]}')
print('\nSecond User Information')
print(userInfo[1])
print('\nName and Mobno of 3rd User')
print(userInfo[2][0],userInfo[2][1])
# Out:
# All Information
# Showing Details Of User 1 : ['abc', 'abc', '@g']
# Showing Details Of User 2 : ['def', '456', '@g']
# Showing Details Of User 3 : ['ghi', '789', '@g']
#
# Second User Information
# ['def', '456', '@g']
#
# Name and Mobno of 3rd User
# ghi 789

# %%
# WITHOUT USING __init__

class userInfo:
    n = "John"
    mn = 123
    e = "j@gmail.com"

    def printUserInfo(self):
        print(self.n,self.mn,self.e)
        

u1 = userInfo()
u2 = userInfo()
u3 = userInfo()

u1.printUserInfo()
u2.printUserInfo()
u3.printUserInfo()
# Out:
# John 123 j@gmail.com
# John 123 j@gmail.com
# John 123 j@gmail.com

# %%
# WITH USING __init__
 
class userInfo:
 
    def __init__(self,name,mobno,email):    # u1,"John",123,"j@gmail.com"        u2,"Alex",456,"al@gmail.com"   u3,"Smith",789,"sm@gmail.com
        self.n = name                       # u1.n = "John"                      u2.n = "Alex"                  u3.n = "Smith"
        self.mn = mobno                     # u1.mn = 123                        u2.mn = 456                    u3.mn = 789
        self.e = email                      # u1.e = "j@gmail.com"               u2.e = "al@gmail.com"          u3.e = "sm@gmail.com"    
 
    def printUserInfo(self):                # printUserInfo(u1)                  printUserInfo(u2)           
        print(self.n,self.mn,self.e)        #  u1.n  u1.mn   u1.e                u2.n  u2.mn  u2.e
 
u1 = userInfo("John",123,"j@gmail.com")
u2 = userInfo("Alex",456,"al@gmail.com")
u3 = userInfo("Smith",789,"sm@gmail.com")
 
print("All Information")

u1.printUserInfo()
u2.printUserInfo()
u3.printUserInfo()
 
print("\nPrint the information of only second user ")
u2.printUserInfo()
 
print("\nPrint the name and mobno of 3rd user ")
print(u3.n , u3.mn)
# Out:
# All Information
# John 123 j@gmail.com
# Alex 456 al@gmail.com
# Smith 789 sm@gmail.com
#
# Print the information of only second user
# Alex 456 al@gmail.com
#
# Print the name and mobno of 3rd user
# Smith 789

# %%
# Procedural + OOPs

class userInfo:

    def __init__(self,name,mobno,email):   
        self.n = name                      
        self.mn = mobno                    
        self.e = email                       

    def printUserInfo(self):                       
        print(self.n,self.mn,self.e)       

objects = []  # Empty List

for i in range(3):
    print(f"Enter Details Of User {i+1}")
    uname = input("Enter Your Name : ")
    umn = input("Enter Your Mobile No. : ")
    uem = input("Enter Your Email : ")

    obj = userInfo(uname,umn,uem)
    objects.append(obj)

# Print All Information 


# Print the information of only second user


# Print the name and mobno of 3rd user
# Out:
# Enter Details Of User 1
# Enter Your Name :  abc
# Enter Your Mobile No. :  123
# Enter Your Email :  @a
# Enter Details Of User 2
# Enter Your Name :  def
# Enter Your Mobile No. :  456
# Enter Your Email :  @d
# Enter Details Of User 3
# Enter Your Name :  ghi
# Enter Your Mobile No. :  789
# Enter Your Email :  @g

# %%
print(objects)
# Out:
# [<__main__.userInfo object at 0x00000192F59C3E00>, <__main__.userInfo object at 0x00000192F69ECCD0>, <__main__.userInfo object at 0x00000192F69ECB90>]

# %%
objects[0].printUserInfo()
# Out:
# abc 123 @a

# %%
objects[1].printUserInfo()
# Out:
# def 456 @d
